# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
#duong dan anh
my_path = 'C:/Users/ducth/Documents/hoctap/thigiacmaytinh/img/clone_ava.jpg'
#doc anh va hien thi
img = Image.open(my_path)
#display img
plt.imshow(img)

# %%
#ve do thi co ban
x = [1, 2, 3, 4, 8]
y = [10, 16, 20, 28, 25]
plt.plot(x, y)
plt.show()

# %%
#ve do thi co ban
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red')
plt.show()

# %%
# ve do thi co ban
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red') # Mau sac
plt.title('Ví dụ về biểu đồ') # Title
plt.show() # Hien thi

# %%
# tat he truc toa do
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

plt.plot(x, y, color='red')  # doi thanh mau do
plt.title('Biểu đồ ví dụ với màu đỏ')  # Title
# Tat he truc toa do
plt.axis('off')  # Tat he truc toa do
plt.show()

# %%
#ve tren hinh anh
#doc anh
im = Image.open(my_path)
x = [100, 100, 400, 400]
y = [200, 300, 532, 350]

plt.imshow(im) # hien thi anh
plt.plot(x,y, 'bo--') 
plt.show()
