# %%
# dấu # dùng cmt
# Shift + Enter: run code và thêm dòng mới

# %%
# CTRL + Enter: run code

# %%
#!pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# thêm thư viện
from PIL import Image

# %%
#khai báo biến chứa thư mục ( / hoặc \\)
dir = 'C:/Users/ducth/Documents/hoctap/thigiacmaytinh/img/'

# %%
#khai báo đường dẫn ảnh
image_path = dir + "clone_ava.jpg"
print(image_path)
# Out:
# C:/Users/ducth/Documents/hoctap/thigiacmaytinh/img/clone_ava.jpg

# %%
# sử dụng Image.open() để đọc ảnh
img01 = Image.open(image_path)

# %%
# hiển thị ảnh
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
# Hiển thị thông tin cơ bản
print("Định dạng ảnh: ", img01.format)
# Out:
# Định dạng ảnh:  JPEG

# %%
# hiển thị kích cỡ ảnh
print("Kích cỡ ảnh: ", img01.size)
# Out:
# Kích cỡ ảnh:  (640, 640)

# %%
# Lưu và chuyển đổi ảnh
new_img_01_path = dir + "new_01.jpg"
new_img_JPG_01_path = dir + "new_01.png"
img01.save(new_img_01_path)
img01.save(new_img_JPG_01_path)

# %%
# đóng tập tin
img01.close()
