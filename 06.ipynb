# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path = 'C:/Users/ducth/Pictures/img/clone_ava.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
# chuyen tu anh RGB sang anh xam
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=640x640>

# %%
# tach RGB thanh 3 tang khac nhau
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=640x640>
# <PIL.Image.Image image mode=L size=640x640>
# <PIL.Image.Image image mode=L size=640x640>

# %%
merged_image = Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>
