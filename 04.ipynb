# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/ducth/Documents/hoctap/thigiacmaytinh/img/clone_ava.jpg'

# %%
#doc anh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
#dinh vi khu vuc muon cat
region = (160,160,480,480)
# cat vung anh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>

# %%
# dan anh
paste_position = (150,320)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>
